# %%
# Set token (private)
# ACCESS_TOKEN = ''

# Load from file
from pathlib import Path
with open(Path.home()/'python/epsman/localSettings/zenodoSettings.dat') as f:
    ACCESS_TOKEN = f.read().strip()

# %%
#*** REST API
# Code from https://developers.zenodo.org/#introduction

import requests

# r = requests.get("https://zenodo.org/api/deposit/depositions", params={'access_token': ACCESS_TOKEN})
# zURL = "https://sandbox.zenodo.org"  # Sandbox URL - gives 401 error?
zURL = "https://zenodo.org"
r = requests.get(f"{zURL}/api/deposit/depositions", params={'access_token': ACCESS_TOKEN})
r.status_code
# r.json()

#  f"{zURL}/api/deposit/depositions"
# Out:
# 200

# %%
# Setup empty upload
headers = {"Content-Type": "application/json"}
r = requests.post('https://zenodo.org/api/deposit/depositions',
                   params={'access_token': ACCESS_TOKEN}, json={},
                   headers=headers)

deposition_id = r.json()['id']

# %%
r.status_code
# Out:
# 201

# %%
r.json()
deposition_id = r.json()['id']

# %%
# Access to json() objects as dict
r.json()['metadata']['prereserve_doi']['doi']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-39-7047bd910554> in <module>
#       1 # Access to json() objects as dict
# ----> 2 r.json()['metadata']['prereserve_doi']['doi']
#
# KeyError: 'metadata'

# %%
# Upload a file

# Get the deposition id from the previous response
# deposition_id = r.json()['id']
# Set file - seems like single file per call
# data = {'name1': 'zenodo_test.py', 'name2': '__init__.py'}
# files = {'file1': open('zenodo_test.py', 'rb'), 'file2': open('__init__.py', 'rb')}
data = {'name': 'zenodo_test.py'}
files = {'file': open('zenodo_test.py', 'rb')}


# Upload
r = requests.post('https://zenodo.org/api/deposit/depositions/%s/files' % deposition_id,
                   params={'access_token': ACCESS_TOKEN}, data=data,
                   files=files)
r.status_code
# Out:
# 201

# %%
print('https://zenodo.org/api/deposit/depositions/%s/files' % deposition_id)
f"https://zenodo.org/api/deposit/depositions/{deposition_id}/files"
# Out:
# https://zenodo.org/api/deposit/depositions/3600654/files
# 'https://zenodo.org/api/deposit/depositions/3600654/files'

# %%
r.json()
# Out:
# {'checksum': 'c956b1409bfd155fc87731f2916ba4f0',
#  'filename': 'zenodo_test.py',
#  'filesize': 197,
#  'id': 'f778fef3-ec2f-4a0c-bfd3-debc2420a996',
#  'links': {'download': 'https://zenodo.org/api/files/176fe5cf-2715-4773-b16b-c94a7cc25578/zenodo_test.py',
#   'self': 'https://zenodo.org/api/deposit/depositions/3600654/files/f778fef3-ec2f-4a0c-bfd3-debc2420a996'}}

# %%
files
# Out:
# {'file1': <_io.BufferedReader name='zenodo_test.py'>,
#  'file2': <_io.BufferedReader name='__init__.py'>}

# %%
# Add metadata
# For schema: https://developers.zenodo.org/#representation
keyURL = 'test'
stringHTML = 'Photoionization calculations with ePolyScat + ePSproc.' + \
             f"\n*Web version*: <a href=http://github.pages/{keyURL}>http://github.pages/{keyURL}</a>" + \
             "\nFor more details of the calculations, see: " + \
             "<ul><li><a href=http://github.pages/about>About the data</a>" + \
             "<li><a href=http://epsproc.readthedocs.io>About the analysis</a></ul>"


data = {
         'metadata': {
             'title': 'My first upload',
             'upload_type': 'dataset',
             'description': stringHTML,
             'creators': [{'name': 'Hockett, Paul',
                           'affiliation': 'National Research Council of Canada',
                           'orcid': '0000-0001-9561-8433'}],
             'access_right': 'open',
             'license': 'CC-BY-4.0',
             'prereserve_doi': True,  # May not be required?
             'keywords':['Data','Photoionization','Scattering calculation']
# ADDITIONAL fields that might be worthwhile.
#              'related_identifiers'
#              'references'
#              'subjects'
#              'version'
#              'method'  # Supports HTML
             
             }
         }

data
# Out:
# {'metadata': {'title': 'My first upload',
#   'upload_type': 'dataset',
#   'description': 'Photoionization calculations with ePolyScat + ePSproc.\n*Web version*: <a href=http://github.pages/test>http://github.pages/test</a>\nFor more details of the calculations, see: <ul><li><a href=http://github.pages/about>About the data</a><li><a href=http://epsproc.readthedocs.io>About the analysis</a></ul>',
#   'creators': [{'name': 'Hockett, Paul',
#     'affiliation': 'National Research Council of Canada',
#     'orcid': '0000-0001-9561-8433'}],
#   'access_right': 'open',
#   'license': 'CC-BY-4.0',
#   'prereserve_doi': True,
#   'keywords': ['Data', 'Photoionization', 'Scattering calculation']}}

# %%
# Add metadata to existing deposition
# r = requests.put('https://zenodo.org/api/deposit/depositions/%s' % deposition_id,
#                   params={'access_token': ACCESS_TOKEN}, data=json.dumps(data),
#                   headers=headers)

# Set new upload with metadata
# Setup empty upload
headers = {"Content-Type": "application/json"}
r = requests.post('https://zenodo.org/api/deposit/depositions',
                   params={'access_token': ACCESS_TOKEN}, json={}, data=json.dumps(data),
                   headers=headers)

deposition_id = r.json()['id']


r.status_code

# 7/01/20 Just set this to see if DOI persists.
# 8/01/20 Yep, still good 24 hr later.
# Out:
# 201

# %%
r.json()
# Out:
# {'conceptrecid': '3600653',
#  'created': '2020-01-08T03:41:19.793826+00:00',
#  'doi': '',
#  'doi_url': 'https://doi.org/',
#  'files': [],
#  'id': 3600654,
#  'links': {'bucket': 'https://zenodo.org/api/files/176fe5cf-2715-4773-b16b-c94a7cc25578',
#   'discard': 'https://zenodo.org/api/deposit/depositions/3600654/actions/discard',
#   'edit': 'https://zenodo.org/api/deposit/depositions/3600654/actions/edit',
#   'files': 'https://zenodo.org/api/deposit/depositions/3600654/files',
#   'html': 'https://zenodo.org/deposit/3600654',
#   'latest_draft': 'https://zenodo.org/api/deposit/depositions/3600654',
#   'latest_draft_html': 'https://zenodo.org/deposit/3600654',
#   'publish': 'https://zenodo.org/api/deposit/depositions/3600654/actions/publish',
#   'self': 'https://zenodo.org/api/deposit/depositions/3600654'},
#  'metadata': {'access_right': 'open',
#   'creators': [{'affiliation': 'National Research Council of Canada',
#     'name': 'Hockett, Paul',
#     'orcid': '0000-0001-9561-8433'}],
#   'description': 'Photoionization calculations with ePolyScat + ePSproc.\n*Web version*: <a href="http://github.pages/test">http://github.pages/test</a>\nFor more details of the calculations, see: <ul><li><a href="http://github.pages/about">About the data</a></li><li><a href="http://epsproc.readthedocs.io">About the analysis</a></li></ul>',
#   'doi': '',
#   'keywords': ['Data', 'Photoionization', 'Scattering calculation'],
#   'license': 'CC-BY-4.0',
#   'prereserve_doi': {'doi': '10.5281/zenodo.3600654', 'recid': 3600654},
#   'publication_date': '2020-01-08',
#   'title': 'My first upload',
#   'upload_type': 'dataset'},
#  'modified': '2020-01-08T03:41:19.793833+00:00',
#  'owner': 85765,
#  'record_id': 3600654,
#  'state': 'unsubmitted',
#  'submitted': False,
#  'title': 'My first upload'}

# %%
dir(r)
# r.ok
# r.reason
r.text
# Out:
# '{"conceptrecid":"3600653","created":"2020-01-08T03:41:19.793826+00:00","doi":"","doi_url":"https://doi.org/","files":[],"id":3600654,"links":{"bucket":"https://zenodo.org/api/files/176fe5cf-2715-4773-b16b-c94a7cc25578","discard":"https://zenodo.org/api/deposit/depositions/3600654/actions/discard","edit":"https://zenodo.org/api/deposit/depositions/3600654/actions/edit","files":"https://zenodo.org/api/deposit/depositions/3600654/files","html":"https://zenodo.org/deposit/3600654","latest_draft":"https://zenodo.org/api/deposit/depositions/3600654","latest_draft_html":"https://zenodo.org/deposit/3600654","publish":"https://zenodo.org/api/deposit/depositions/3600654/actions/publish","self":"https://zenodo.org/api/deposit/depositions/3600654"},"metadata":{"access_right":"open","creators":[{"affiliation":"National Research Council of Canada","name":"Hockett, Paul","orcid":"0000-0001-9561-8433"}],"description":"Photoionization calculations with ePolyScat + ePSproc.\\n*Web version*: <a href=\\"http://github.pages/test\\">http://github.pages/test</a>\\nFor more details of the calculations, see: <ul><li><a href=\\"http://github.pages/about\\">About the data</a></li><li><a href=\\"http://epsproc.readthedocs.io\\">About the analysis</a></li></ul>","doi":"","keywords":["Data","Photoionization","Scattering calculation"],"license":"CC-BY-4.0","prereserve_doi":{"doi":"10.5281/zenodo.3600654","recid":3600654},"publication_date":"2020-01-08","title":"My first upload","upload_type":"dataset"},"modified":"2020-01-08T03:41:19.793833+00:00","owner":85765,"record_id":3600654,"state":"unsubmitted","submitted":false,"title":"My first upload"}'

# %%
# Publish post - not until ready!
### r = requests.post('https://zenodo.org/api/deposit/depositions/%s/actions/publish' % deposition_id,
###                      params={'access_token': ACCESS_TOKEN} )

# %%
# Delete item (for unpublished items only)
r = requests.delete('https://zenodo.org/api/deposit/depositions/%s' % deposition_id,
                    params={'access_token': ACCESS_TOKEN})
r.status_code
# Out:
# 204

# %%
r.ok
# Out:
# True

# %% [markdown]
# # List for current user

# %%
# By ID
ID = '3660702'
response = requests.get(f"https://zenodo.org/api/deposit/depositions/{ID}?access_token={ACCESS_TOKEN}")

# %%
# https://developers.zenodo.org/#list
response = requests.get('https://zenodo.org/api/deposit/depositions',
                        params={'q': 'XeF2',
                                'access_token': ACCESS_TOKEN})
# print(response.json())

# %%
import pprint
pp = pprint.PrettyPrinter(indent=1)
pp.pprint(response.json())
# Out:
# [{'conceptrecid': '3676898',
#   'created': '2020-02-20T13:32:24.540661',
#   'doi': '',
#   'doi_url': 'https://doi.org/',
#   'files': [{'checksum': '81344c7b1e377411b267941ff04dadf7',
#              'filename': 'readme.txt',
#              'filesize': 863,
#              'id': '5101de5b-857c-47ee-8691-17a86f9c27c9',
#              'links': {'download': 'https://zenodo.org/api/files/1ffc43d7-b7b9-4911-b073-77f165aa71ee/readme.txt',
#                        'self': 'https://zenodo.org/api/deposit/depositions/3676899/files/5101de5b-857c-47ee-8691-17a86f9c27c9'}},
#             {'checksum': 'bf8d9c6eef4cf08c68c067e645762fae',
#              'filename': 'xef2_1.0-60.1eV_orb21_A1G.ipynb',
#              'filesize': 811379,
#              'id': '207004c0-246e-4c34-96a6-2a684abe4aba',
#              'links': {'download': 'https://zenodo.org/api/files/1ffc43d7-b7b9-4911-b073-77f165aa71ee/xef2_1.0-60.1eV_orb21_A1G.ipynb',
#                        'self': 'https://zenodo.org/api/deposit/depositions/3676899/files/207004c0-246e-4c34-96a6-2a684abe4aba'}},
#             {'checksum': 'caf3d8146e78f33232e27f543d5ff807',
#              'filename': 'xef2_1.0-60.1eV_orb21_A1G.md',
#              'filesize': 2301,
#              'id': 'dc2f3d01-9659-4bdb-9894-af9d5e378e5d',
#              'links': {'download': 'https://zenodo.org/api/files/1ffc43d7-b7b9-4911-b073-77f165aa71ee/xef2_1.0-60.1eV_orb21_A1G.md',
#                        'self': 'https://zenodo.org/api/deposit/depositions/3676899/files/dc2f3d01-9659-4bdb-9894-af9d5e378e5d'}},
#             {'checksum': '980f5744aead7e5f4a36d47347aa980a',
#              'filename': 'xef2_1.0-60.1eV_orb21_A1G.json',
#              'filesize': 38109,
#              'id': '26ebf776-e843-4d8f-8e7e-71b5207e652d',
#              'links': {'download': 'https://zenodo.org/api/files/1ffc43d7-b7b9-4911-b073-77f165aa71ee/xef2_1.0-60.1eV_orb21_A1G.json',
#                        'self': 'https://zenodo.org/api/deposit/depositions/3676899/files/26ebf776-e843-4d8f-8e7e-71b5207e652d'}},
#             {'checksum': 'f2d276e08b31ca2a277d0c6d89563249',
#              'filename': 'xef2_1.0-60.1eV_orb21_A1G.zip',
#              'filesize': 19308472,
#              'id': 'd935a2a2-c2e2-4050-9967-0fcf65a17a15',
#              'links': {'download': 'https://zenodo.org/api/files/1ffc43d7-b7b9-4911-b073-77f165aa71ee/xef2_1.0-60.1eV_orb21_A1G.zip',
#                        'self': 'https://zenodo.org/api/deposit/depositions/3676899/files/d935a2a2-c2e2-4050-9967-0fcf65a17a15'}}],
#   'id': 3676899,
#   'links': {'bucket': 'https://zenodo.org/api/files/1ffc43d7-b7b9-4911-b073-77f165aa71ee',
#             'discard': 'https://zenodo.org/api/deposit/depositions/3676899/actions/discard',
#             'edit': 'https://zenodo.org/api/deposit/depositions/3676899/actions/edit',
#             'files': 'https://zenodo.org/api/deposit/depositions/3676899/files',
#             'html': 'https://zenodo.org/deposit/3676899',
#             'latest_draft': 'https://zenodo.org/api/deposit/depositions/3676899',
#             'latest_draft_html': 'https://zenodo.org/deposit/3676899',
#             'publish': 'https://zenodo.org/api/deposit/depositions/3676899/actions/publish',
#             'self': 'https://zenodo.org/api/deposit/depositions/3676899'},
#   'metadata': {'access_right': 'open',
#                'creators': [{'affiliation': 'National Research Council of '
#                                             'Canada',
#                              'name': 'Hockett, Paul',
#                              'orcid': '0000-0001-9561-8433'}],
#                'description': 'xef2 wavefn test run, orb 21 ioinzation (Iodine '
#                               '4d, A1G/SG), 1-60eV - photoionization '
#                               'calculations with ePolyScat (ePS) + '
#                               'ePSproc.<br><br>*Web version*: <a '
#                               'href="https://phockett.github.io/ePSdata/xef2_1.0-60.1eV/xef2_1.0-60.1eV_orb21_A1G.html">https://phockett.github.io/ePSdata/xef2_1.0-60.1eV/xef2_1.0-60.1eV_orb21_A1G.html</a><br><br>For '
#                               'more details of the calculations, see '
#                               'readme.txt, or: <ul><li><a '
#                               'href="https://phockett.github.io/ePSdata/about.html">About '
#                               'ePSdata</a></li><li><a '
#                               'href="http://epsproc.readthedocs.io/en/latest/about.html">About '
#                               'ePSproc</a></li><li><a '
#                               'href="http://www.chem.tamu.edu/rgroup/lucchese/ePolyScat.E3.manual/manual.html">About '
#                               'ePS</a></li></ul>',
#                'doi': '',
#                'keywords': ['Data',
#                             'Photoionization',
#                             'Scattering calculation'],
#                'license': 'CC-BY-4.0',
#                'prereserve_doi': {'doi': '10.5281/zenodo.3676899',
#                                   'recid': 3676899},
#                'publication_date': '2020-02-20',
#                'title': 'ePSproc: xef2 wavefn test run, orb 21 ioinzation '
#                         '(Iodine 4d, A1G/SG), 1-60eV',
#                'upload_type': 'dataset'},
#   'modified': '2020-02-20T13:41:11.647422',
#   'owner': 85765,
#   'record_id': 3676899,
#   'state': 'unsubmitted',
#   'submitted': False,
#   'title': 'ePSproc: xef2 wavefn test run, orb 21 ioinzation (Iodine 4d, '
#            'A1G/SG), 1-60eV'},
#  {'conceptrecid': '3676892',
#   'created': '2020-02-20T13:32:05.910326',
#   'doi': '',
#   'doi_url': 'https://doi.org/',
#   'files': [{'checksum': '81344c7b1e377411b267941ff04dadf7',
#              'filename': 'readme.txt',
#              'filesize': 863,
#              'id': 'f92c9644-85cc-4c0d-96b8-44c27a1bcbeb',
#              'links': {'download': 'https://zenodo.org/api/files/5351af9c-1dda-420d-a601-035f0d89633e/readme.txt',
#                        'self': 'https://zenodo.org/api/deposit/depositions/3676893/files/f92c9644-85cc-4c0d-96b8-44c27a1bcbeb'}},
#             {'checksum': '75737726297b6774e40ac1709763ad0f',
#              'filename': 'xef2_1.0-60.1eV_orb12_A1G.ipynb',
#              'filesize': 784717,
#              'id': '5b374297-4dea-4f41-8138-a3c5b172d9c6',
#              'links': {'download': 'https://zenodo.org/api/files/5351af9c-1dda-420d-a601-035f0d89633e/xef2_1.0-60.1eV_orb12_A1G.ipynb',
#                        'self': 'https://zenodo.org/api/deposit/depositions/3676893/files/5b374297-4dea-4f41-8138-a3c5b172d9c6'}},
#             {'checksum': 'f4fe8b322b4e4000cb8f297ac8de390e',
#              'filename': 'xef2_1.0-60.1eV_orb12_A1G.md',
#              'filesize': 2276,
#              'id': '94dc20f3-d35c-4d7e-b8b2-9009c746b7d2',
#              'links': {'download': 'https://zenodo.org/api/files/5351af9c-1dda-420d-a601-035f0d89633e/xef2_1.0-60.1eV_orb12_A1G.md',
#                        'self': 'https://zenodo.org/api/deposit/depositions/3676893/files/94dc20f3-d35c-4d7e-b8b2-9009c746b7d2'}},
#             {'checksum': '564152111eb7ad69b49cad63205a1217',
#              'filename': 'xef2_1.0-60.1eV_orb12_A1G.json',
#              'filesize': 38074,
#              'id': '6ecdb134-a879-42b1-9d31-7f55870db431',
#              'links': {'download': 'https://zenodo.org/api/files/5351af9c-1dda-420d-a601-035f0d89633e/xef2_1.0-60.1eV_orb12_A1G.json',
#                        'self': 'https://zenodo.org/api/deposit/depositions/3676893/files/6ecdb134-a879-42b1-9d31-7f55870db431'}},
#             {'checksum': '242446dd39742f8c109809f417dd704c',
#              'filename': 'xef2_1.0-60.1eV_orb12_A1G.zip',
#              'filesize': 19271073,
#              'id': '32a1a1f8-6c67-45fe-a384-0fa9976921a2',
#              'links': {'download': 'https://zenodo.org/api/files/5351af9c-1dda-420d-a601-035f0d89633e/xef2_1.0-60.1eV_orb12_A1G.zip',
#                        'self': 'https://zenodo.org/api/deposit/depositions/3676893/files/32a1a1f8-6c67-45fe-a384-0fa9976921a2'}}],
#   'id': 3676893,
#   'links': {'bucket': 'https://zenodo.org/api/files/5351af9c-1dda-420d-a601-035f0d89633e',
#             'discard': 'https://zenodo.org/api/deposit/depositions/3676893/actions/discard',
#             'edit': 'https://zenodo.org/api/deposit/depositions/3676893/actions/edit',
#             'files': 'https://zenodo.org/api/deposit/depositions/3676893/files',
#             'html': 'https://zenodo.org/deposit/3676893',
#             'latest_draft': 'https://zenodo.org/api/deposit/depositions/3676893',
#             'latest_draft_html': 'https://zenodo.org/deposit/3676893',
#             'publish': 'https://zenodo.org/api/deposit/depositions/3676893/actions/publish',
#             'self': 'https://zenodo.org/api/deposit/depositions/3676893'},
#   'metadata': {'access_right': 'open',
#                'creators': [{'affiliation': 'National Research Council of '
#                                             'Canada',
#                              'name': 'Hockett, Paul',
#                              'orcid': '0000-0001-9561-8433'}],
#                'description': 'xef2 wavefn run, orb 12 ioinzation (Iodine 3d, '
#                               'A1G/SG), 1-60eV - photoionization calculations '
#                               'with ePolyScat (ePS) + ePSproc.<br><br>*Web '
#                               'version*: <a '
#                               'href="https://phockett.github.io/ePSdata/xef2_1.0-60.1eV/xef2_1.0-60.1eV_orb12_A1G.html">https://phockett.github.io/ePSdata/xef2_1.0-60.1eV/xef2_1.0-60.1eV_orb12_A1G.html</a><br><br>For '
#                               'more details of the calculations, see '
#                               'readme.txt, or: <ul><li><a '
#                               'href="https://phockett.github.io/ePSdata/about.html">About '
#                               'ePSdata</a></li><li><a '
#                               'href="http://epsproc.readthedocs.io/en/latest/about.html">About '
#                               'ePSproc</a></li><li><a '
#                               'href="http://www.chem.tamu.edu/rgroup/lucchese/ePolyScat.E3.manual/manual.html">About '
#                               'ePS</a></li></ul>',
#                'doi': '',
#                'keywords': ['Data',
#                             'Photoionization',
#                             'Scattering calculation'],
#                'license': 'CC-BY-4.0',
#                'prereserve_doi': {'doi': '10.5281/zenodo.3676893',
#                                   'recid': 3676893},
#                'publication_date': '2020-02-20',
#                'title': 'ePSproc: xef2 wavefn run, orb 12 ioinzation (Iodine '
#                         '3d, A1G/SG), 1-60eV',
#                'upload_type': 'dataset'},
#   'modified': '2020-02-20T13:40:18.495033',
#   'owner': 85765,
#   'record_id': 3676893,
#   'state': 'unsubmitted',
#   'submitted': False,
#   'title': 'ePSproc: xef2 wavefn run, orb 12 ioinzation (Iodine 3d, A1G/SG), '
#            '1-60eV'},
#  {'conceptrecid': '3676902',
#   'created': '2020-02-20T13:32:35.754802',
#   'doi': '',
#   'doi_url': 'https://doi.org/',
#   'files': [{'checksum': '81344c7b1e377411b267941ff04dadf7',
#              'filename': 'readme.txt',
#              'filesize': 863,
#              'id': 'b3f2a927-a10b-414e-96fc-848dd7a30edf',
#              'links': {'download': 'https://zenodo.org/api/files/92b61fd6-4579-4ed4-8529-d2f6374f5276/readme.txt',
#                        'self': 'https://zenodo.org/api/deposit/depositions/3676903/files/b3f2a927-a10b-414e-96fc-848dd7a30edf'}},
#             {'checksum': 'fbd65e8d23a2e881ad630f4d07ce7326',
#              'filename': 'xef2_1.0-60.1eV_orb24_E2G.ipynb',
#              'filesize': 837774,
#              'id': '29ce93a5-0018-4f7d-9c91-78b8caf2043e',
#              'links': {'download': 'https://zenodo.org/api/files/92b61fd6-4579-4ed4-8529-d2f6374f5276/xef2_1.0-60.1eV_orb24_E2G.ipynb',
#                        'self': 'https://zenodo.org/api/deposit/depositions/3676903/files/29ce93a5-0018-4f7d-9c91-78b8caf2043e'}},
#             {'checksum': '15600f7a16cb6a581cf57f6f6f7c6140',
#              'filename': 'xef2_1.0-60.1eV_orb24_E2G.md',
#              'filesize': 2301,
#              'id': 'bf50fc5b-b3d5-4ec4-a303-a577672507e4',
#              'links': {'download': 'https://zenodo.org/api/files/92b61fd6-4579-4ed4-8529-d2f6374f5276/xef2_1.0-60.1eV_orb24_E2G.md',
#                        'self': 'https://zenodo.org/api/deposit/depositions/3676903/files/bf50fc5b-b3d5-4ec4-a303-a577672507e4'}},
#             {'checksum': '70f4d724735fd2689f44e317e2f2f0e8',
#              'filename': 'xef2_1.0-60.1eV_orb24_E2G.json',
#              'filesize': 54717,
#              'id': 'dab9dcdf-a2fb-4457-95cf-4a4bf5be611b',
#              'links': {'download': 'https://zenodo.org/api/files/92b61fd6-4579-4ed4-8529-d2f6374f5276/xef2_1.0-60.1eV_orb24_E2G.json',
#                        'self': 'https://zenodo.org/api/deposit/depositions/3676903/files/dab9dcdf-a2fb-4457-95cf-4a4bf5be611b'}},
#             {'checksum': '006b208049251cf78e588ffbd9b5571b',
#              'filename': 'xef2_1.0-60.1eV_orb24_E2G.zip',
#              'filesize': 32434456,
#              'id': '0fbcb6e0-da33-4b73-ad3f-0ce9ed7e6cad',
#              'links': {'download': 'https://zenodo.org/api/files/92b61fd6-4579-4ed4-8529-d2f6374f5276/xef2_1.0-60.1eV_orb24_E2G.zip',
#                        'self': 'https://zenodo.org/api/deposit/depositions/3676903/files/0fbcb6e0-da33-4b73-ad3f-0ce9ed7e6cad'}}],
#   'id': 3676903,
#   'links': {'bucket': 'https://zenodo.org/api/files/92b61fd6-4579-4ed4-8529-d2f6374f5276',
#             'discard': 'https://zenodo.org/api/deposit/depositions/3676903/actions/discard',
#             'edit': 'https://zenodo.org/api/deposit/depositions/3676903/actions/edit',
#             'files': 'https://zenodo.org/api/deposit/depositions/3676903/files',
#             'html': 'https://zenodo.org/deposit/3676903',
#             'latest_draft': 'https://zenodo.org/api/deposit/depositions/3676903',
#             'latest_draft_html': 'https://zenodo.org/deposit/3676903',
#             'publish': 'https://zenodo.org/api/deposit/depositions/3676903/actions/publish',
#             'self': 'https://zenodo.org/api/deposit/depositions/3676903'},
#   'metadata': {'access_right': 'open',
#                'creators': [{'affiliation': 'National Research Council of '
#                                             'Canada',
#                              'name': 'Hockett, Paul',
#                              'orcid': '0000-0001-9561-8433'}],
#                'description': 'xef2 wavefn test run, orb 24 ioinzation (Iodine '
#                               '4d, E2G/DG), 1-60eV - photoionization '
#                               'calculations with ePolyScat (ePS) + '
#                               'ePSproc.<br><br>*Web version*: <a '
#                               'href="https://phockett.github.io/ePSdata/xef2_1.0-60.1eV/xef2_1.0-60.1eV_orb24_E2G.html">https://phockett.github.io/ePSdata/xef2_1.0-60.1eV/xef2_1.0-60.1eV_orb24_E2G.html</a><br><br>For '
#                               'more details of the calculations, see '
#                               'readme.txt, or: <ul><li><a '
#                               'href="https://phockett.github.io/ePSdata/about.html">About '
#                               'ePSdata</a></li><li><a '
#                               'href="http://epsproc.readthedocs.io/en/latest/about.html">About '
#                               'ePSproc</a></li><li><a '
#                               'href="http://www.chem.tamu.edu/rgroup/lucchese/ePolyScat.E3.manual/manual.html">About '
#                               'ePS</a></li></ul>',
#                'doi': '',
#                'keywords': ['Data',
#                             'Photoionization',
#                             'Scattering calculation'],
#                'license': 'CC-BY-4.0',
#                'prereserve_doi': {'doi': '10.5281/zenodo.3676903',
#                                   'recid': 3676903},
#                'publication_date': '2020-02-20',
#                'title': 'ePSproc: xef2 wavefn test run, orb 24 ioinzation '
#                         '(Iodine 4d, E2G/DG), 1-60eV',
#                'upload_type': 'dataset'},
#   'modified': '2020-02-20T13:41:45.086862',
#   'owner': 85765,
#   'record_id': 3676903,
#   'state': 'unsubmitted',
#   'submitted': False,
#   'title': 'ePSproc: xef2 wavefn test run, orb 24 ioinzation (Iodine 4d, '
#            'E2G/DG), 1-60eV'},
#  {'conceptrecid': '3676900',
#   'created': '2020-02-20T13:32:29.739263',
#   'doi': '',
#   'doi_url': 'https://doi.org/',
#   'files': [{'checksum': '81344c7b1e377411b267941ff04dadf7',
#              'filename': 'readme.txt',
#              'filesize': 863,
#              'id': '528a29a1-cbc3-4336-86a3-4b2c091a7be3',
#              'links': {'download': 'https://zenodo.org/api/files/c5446db7-b160-4e6b-81b1-bc0e96ef2f67/readme.txt',
#                        'self': 'https://zenodo.org/api/deposit/depositions/3676901/files/528a29a1-cbc3-4336-86a3-4b2c091a7be3'}},
#             {'checksum': 'fc6ffa02482ff7d9d1c331ca79f39669',
#              'filename': 'xef2_1.0-60.1eV_orb22_E1G.ipynb',
#              'filesize': 866260,
#              'id': '571a2da9-85d0-42e3-9075-06d7bfebaf4e',
#              'links': {'download': 'https://zenodo.org/api/files/c5446db7-b160-4e6b-81b1-bc0e96ef2f67/xef2_1.0-60.1eV_orb22_E1G.ipynb',
#                        'self': 'https://zenodo.org/api/deposit/depositions/3676901/files/571a2da9-85d0-42e3-9075-06d7bfebaf4e'}},
#             {'checksum': '6b70ed0bb00ddf1d79f2dbd0fd6f5261',
#              'filename': 'xef2_1.0-60.1eV_orb22_E1G.md',
#              'filesize': 2301,
#              'id': '7891da75-e06a-49fb-8d45-cdbe18e165e7',
#              'links': {'download': 'https://zenodo.org/api/files/c5446db7-b160-4e6b-81b1-bc0e96ef2f67/xef2_1.0-60.1eV_orb22_E1G.md',
#                        'self': 'https://zenodo.org/api/deposit/depositions/3676901/files/7891da75-e06a-49fb-8d45-cdbe18e165e7'}},
#             {'checksum': '5e281a98dba384cdce5ac07efb1adb50',
#              'filename': 'xef2_1.0-60.1eV_orb22_E1G.json',
#              'filesize': 54717,
#              'id': 'f93e752c-64af-49e1-9129-91b96d44966b',
#              'links': {'download': 'https://zenodo.org/api/files/c5446db7-b160-4e6b-81b1-bc0e96ef2f67/xef2_1.0-60.1eV_orb22_E1G.json',
#                        'self': 'https://zenodo.org/api/deposit/depositions/3676901/files/f93e752c-64af-49e1-9129-91b96d44966b'}},
#             {'checksum': 'c33da1b5505568061ece5b2a0c88f710',
#              'filename': 'xef2_1.0-60.1eV_orb22_E1G.zip',
#              'filesize': 30430091,
#              'id': '89c6e322-0d34-4d49-bee6-133b27304dc6',
#              'links': {'download': 'https://zenodo.org/api/files/c5446db7-b160-4e6b-81b1-bc0e96ef2f67/xef2_1.0-60.1eV_orb22_E1G.zip',
#                        'self': 'https://zenodo.org/api/deposit/depositions/3676901/files/89c6e322-0d34-4d49-bee6-133b27304dc6'}}],
#   'id': 3676901,
#   'links': {'bucket': 'https://zenodo.org/api/files/c5446db7-b160-4e6b-81b1-bc0e96ef2f67',
#             'discard': 'https://zenodo.org/api/deposit/depositions/3676901/actions/discard',
#             'edit': 'https://zenodo.org/api/deposit/depositions/3676901/actions/edit',
#             'files': 'https://zenodo.org/api/deposit/depositions/3676901/files',
#             'html': 'https://zenodo.org/deposit/3676901',
#             'latest_draft': 'https://zenodo.org/api/deposit/depositions/3676901',
#             'latest_draft_html': 'https://zenodo.org/deposit/3676901',
#             'publish': 'https://zenodo.org/api/deposit/depositions/3676901/actions/publish',
#             'self': 'https://zenodo.org/api/deposit/depositions/3676901'},
#   'metadata': {'access_right': 'open',
#                'creators': [{'affiliation': 'National Research Council of '
#                                             'Canada',
#                              'name': 'Hockett, Paul',
#                              'orcid': '0000-0001-9561-8433'}],
#                'description': 'xef2 wavefn test run, orb 22 ioinzation (Iodine '
#                               '4d, E1G/PG), 1-60eV - photoionization '
#                               'calculations with ePolyScat (ePS) + '
#                               'ePSproc.<br><br>*Web version*: <a '
#                               'href="https://phockett.github.io/ePSdata/xef2_1.0-60.1eV/xef2_1.0-60.1eV_orb22_E1G.html">https://phockett.github.io/ePSdata/xef2_1.0-60.1eV/xef2_1.0-60.1eV_orb22_E1G.html</a><br><br>For '
#                               'more details of the calculations, see '
#                               'readme.txt, or: <ul><li><a '
#                               'href="https://phockett.github.io/ePSdata/about.html">About '
#                               'ePSdata</a></li><li><a '
#                               'href="http://epsproc.readthedocs.io/en/latest/about.html">About '
#                               'ePSproc</a></li><li><a '
#                               'href="http://www.chem.tamu.edu/rgroup/lucchese/ePolyScat.E3.manual/manual.html">About '
#                               'ePS</a></li></ul>',
#                'doi': '',
#                'keywords': ['Data',
#                             'Photoionization',
#                             'Scattering calculation'],
#                'license': 'CC-BY-4.0',
#                'prereserve_doi': {'doi': '10.5281/zenodo.3676901',
#                                   'recid': 3676901},
#                'publication_date': '2020-02-20',
#                'title': 'ePSproc: xef2 wavefn test run, orb 22 ioinzation '
#                         '(Iodine 4d, E1G/PG), 1-60eV',
#                'upload_type': 'dataset'},
#   'modified': '2020-02-20T13:41:28.863916',
#   'owner': 85765,
#   'record_id': 3676901,
#   'state': 'unsubmitted',
#   'submitted': False,
#   'title': 'ePSproc: xef2 wavefn test run, orb 22 ioinzation (Iodine 4d, '
#            'E1G/PG), 1-60eV'},
#  {'conceptrecid': '3676896',
#   'created': '2020-02-20T13:32:19.409822',
#   'doi': '',
#   'doi_url': 'https://doi.org/',
#   'files': [{'checksum': '81344c7b1e377411b267941ff04dadf7',
#              'filename': 'readme.txt',
#              'filesize': 863,
#              'id': '91463cb0-3438-46f1-8e87-8058234761f8',
#              'links': {'download': 'https://zenodo.org/api/files/9843751a-780e-40dd-8ba0-4006491d2db1/readme.txt',
#                        'self': 'https://zenodo.org/api/deposit/depositions/3676897/files/91463cb0-3438-46f1-8e87-8058234761f8'}},
#             {'checksum': 'c398d3993ac5b31e21a15f9ba3707f77',
#              'filename': 'xef2_1.0-60.1eV_orb15_E2G.ipynb',
#              'filesize': 753785,
#              'id': '1be5d23e-b7e9-4207-9145-bf3bf3b80f56',
#              'links': {'download': 'https://zenodo.org/api/files/9843751a-780e-40dd-8ba0-4006491d2db1/xef2_1.0-60.1eV_orb15_E2G.ipynb',
#                        'self': 'https://zenodo.org/api/deposit/depositions/3676897/files/1be5d23e-b7e9-4207-9145-bf3bf3b80f56'}},
#             {'checksum': '0be9dc0da92b2600e7ef1bcc6a83852c',
#              'filename': 'xef2_1.0-60.1eV_orb15_E2G.md',
#              'filesize': 2276,
#              'id': 'd478bd76-a50c-47b2-bd74-f348895c0165',
#              'links': {'download': 'https://zenodo.org/api/files/9843751a-780e-40dd-8ba0-4006491d2db1/xef2_1.0-60.1eV_orb15_E2G.md',
#                        'self': 'https://zenodo.org/api/deposit/depositions/3676897/files/d478bd76-a50c-47b2-bd74-f348895c0165'}},
#             {'checksum': '929e1713c95faf89a64fa29d8aae15bd',
#              'filename': 'xef2_1.0-60.1eV_orb15_E2G.json',
#              'filesize': 54672,
#              'id': '8bcaed5d-ba28-4b0b-8101-c4e78a0fc2b4',
#              'links': {'download': 'https://zenodo.org/api/files/9843751a-780e-40dd-8ba0-4006491d2db1/xef2_1.0-60.1eV_orb15_E2G.json',
#                        'self': 'https://zenodo.org/api/deposit/depositions/3676897/files/8bcaed5d-ba28-4b0b-8101-c4e78a0fc2b4'}},
#             {'checksum': '06528fedaf1065a37835ff5c692a48bf',
#              'filename': 'xef2_1.0-60.1eV_orb15_E2G.zip',
#              'filesize': 32245188,
#              'id': 'b6fe9a1e-6916-48ad-a02c-5b563704c437',
#              'links': {'download': 'https://zenodo.org/api/files/9843751a-780e-40dd-8ba0-4006491d2db1/xef2_1.0-60.1eV_orb15_E2G.zip',
#                        'self': 'https://zenodo.org/api/deposit/depositions/3676897/files/b6fe9a1e-6916-48ad-a02c-5b563704c437'}}],
#   'id': 3676897,
#   'links': {'bucket': 'https://zenodo.org/api/files/9843751a-780e-40dd-8ba0-4006491d2db1',
#             'discard': 'https://zenodo.org/api/deposit/depositions/3676897/actions/discard',
#             'edit': 'https://zenodo.org/api/deposit/depositions/3676897/actions/edit',
#             'files': 'https://zenodo.org/api/deposit/depositions/3676897/files',
#             'html': 'https://zenodo.org/deposit/3676897',
#             'latest_draft': 'https://zenodo.org/api/deposit/depositions/3676897',
#             'latest_draft_html': 'https://zenodo.org/deposit/3676897',
#             'publish': 'https://zenodo.org/api/deposit/depositions/3676897/actions/publish',
#             'self': 'https://zenodo.org/api/deposit/depositions/3676897'},
#   'metadata': {'access_right': 'open',
#                'creators': [{'affiliation': 'National Research Council of '
#                                             'Canada',
#                              'name': 'Hockett, Paul',
#                              'orcid': '0000-0001-9561-8433'}],
#                'description': 'xef2 wavefn run, orb 15 ioinzation (Iodine 3d, '
#                               'E2G/DG), 1-60eV - photoionization calculations '
#                               'with ePolyScat (ePS) + ePSproc.<br><br>*Web '
#                               'version*: <a '
#                               'href="https://phockett.github.io/ePSdata/xef2_1.0-60.1eV/xef2_1.0-60.1eV_orb15_E2G.html">https://phockett.github.io/ePSdata/xef2_1.0-60.1eV/xef2_1.0-60.1eV_orb15_E2G.html</a><br><br>For '
#                               'more details of the calculations, see '
#                               'readme.txt, or: <ul><li><a '
#                               'href="https://phockett.github.io/ePSdata/about.html">About '
#                               'ePSdata</a></li><li><a '
#                               'href="http://epsproc.readthedocs.io/en/latest/about.html">About '
#                               'ePSproc</a></li><li><a '
#                               'href="http://www.chem.tamu.edu/rgroup/lucchese/ePolyScat.E3.manual/manual.html">About '
#                               'ePS</a></li></ul>',
#                'doi': '',
#                'keywords': ['Data',
#                             'Photoionization',
#                             'Scattering calculation'],
#                'license': 'CC-BY-4.0',
#                'prereserve_doi': {'doi': '10.5281/zenodo.3676897',
#                                   'recid': 3676897},
#                'publication_date': '2020-02-20',
#                'title': 'ePSproc: xef2 wavefn run, orb 15 ioinzation (Iodine '
#                         '3d, E2G/DG), 1-60eV',
#                'upload_type': 'dataset'},
#   'modified': '2020-02-20T13:40:55.761975',
#   'owner': 85765,
#   'record_id': 3676897,
#   'state': 'unsubmitted',
#   'submitted': False,
#   'title': 'ePSproc: xef2 wavefn run, orb 15 ioinzation (Iodine 3d, E2G/DG), '
#            '1-60eV'},
#  {'conceptrecid': '3676894',
#   'created': '2020-02-20T13:32:13.601074',
#   'doi': '',
#   'doi_url': 'https://doi.org/',
#   'files': [{'checksum': '81344c7b1e377411b267941ff04dadf7',
#              'filename': 'readme.txt',
#              'filesize': 863,
#              'id': 'dbf86bbe-4b8e-48df-97b8-e43a00940ae5',
#              'links': {'download': 'https://zenodo.org/api/files/e58ac069-74f8-4e44-a320-2ec6ee847211/readme.txt',
#                        'self': 'https://zenodo.org/api/deposit/depositions/3676895/files/dbf86bbe-4b8e-48df-97b8-e43a00940ae5'}},
#             {'checksum': 'e7667bd5a07b354efddd0370e1975c1b',
#              'filename': 'xef2_1.0-60.1eV_orb13_E1G.ipynb',
#              'filesize': 856184,
#              'id': 'b4ce165b-11d6-4bc1-bd1b-68387baa2640',
#              'links': {'download': 'https://zenodo.org/api/files/e58ac069-74f8-4e44-a320-2ec6ee847211/xef2_1.0-60.1eV_orb13_E1G.ipynb',
#                        'self': 'https://zenodo.org/api/deposit/depositions/3676895/files/b4ce165b-11d6-4bc1-bd1b-68387baa2640'}},
#             {'checksum': '278cdb0de60783abaacb27818734993b',
#              'filename': 'xef2_1.0-60.1eV_orb13_E1G.md',
#              'filesize': 2276,
#              'id': '8681bc0d-c9dd-4ccd-a188-08270b528b96',
#              'links': {'download': 'https://zenodo.org/api/files/e58ac069-74f8-4e44-a320-2ec6ee847211/xef2_1.0-60.1eV_orb13_E1G.md',
#                        'self': 'https://zenodo.org/api/deposit/depositions/3676895/files/8681bc0d-c9dd-4ccd-a188-08270b528b96'}},
#             {'checksum': '84951c0b6b871d578b659d844cb6057f',
#              'filename': 'xef2_1.0-60.1eV_orb13_E1G.json',
#              'filesize': 54672,
#              'id': '2bf0ad37-c8d7-4c76-8256-bdace46e77db',
#              'links': {'download': 'https://zenodo.org/api/files/e58ac069-74f8-4e44-a320-2ec6ee847211/xef2_1.0-60.1eV_orb13_E1G.json',
#                        'self': 'https://zenodo.org/api/deposit/depositions/3676895/files/2bf0ad37-c8d7-4c76-8256-bdace46e77db'}},
#             {'checksum': '858da52d245719eb1a6ba9da62545c54',
#              'filename': 'xef2_1.0-60.1eV_orb13_E1G.zip',
#              'filesize': 30227423,
#              'id': '7b4c6e49-58cc-48f4-b1ba-381a6ab9b8e3',
#              'links': {'download': 'https://zenodo.org/api/files/e58ac069-74f8-4e44-a320-2ec6ee847211/xef2_1.0-60.1eV_orb13_E1G.zip',
#                        'self': 'https://zenodo.org/api/deposit/depositions/3676895/files/7b4c6e49-58cc-48f4-b1ba-381a6ab9b8e3'}}],
#   'id': 3676895,
#   'links': {'bucket': 'https://zenodo.org/api/files/e58ac069-74f8-4e44-a320-2ec6ee847211',
#             'discard': 'https://zenodo.org/api/deposit/depositions/3676895/actions/discard',
#             'edit': 'https://zenodo.org/api/deposit/depositions/3676895/actions/edit',
#             'files': 'https://zenodo.org/api/deposit/depositions/3676895/files',
#             'html': 'https://zenodo.org/deposit/3676895',
#             'latest_draft': 'https://zenodo.org/api/deposit/depositions/3676895',
#             'latest_draft_html': 'https://zenodo.org/deposit/3676895',
#             'publish': 'https://zenodo.org/api/deposit/depositions/3676895/actions/publish',
#             'self': 'https://zenodo.org/api/deposit/depositions/3676895'},
#   'metadata': {'access_right': 'open',
#                'creators': [{'affiliation': 'National Research Council of '
#                                             'Canada',
#                              'name': 'Hockett, Paul',
#                              'orcid': '0000-0001-9561-8433'}],
#                'description': 'xef2 wavefn run, orb 13 ioinzation (Iodine 3d, '
#                               'E1G/PG), 1-60eV - photoionization calculations '
#                               'with ePolyScat (ePS) + ePSproc.<br><br>*Web '
#                               'version*: <a '
#                               'href="https://phockett.github.io/ePSdata/xef2_1.0-60.1eV/xef2_1.0-60.1eV_orb13_E1G.html">https://phockett.github.io/ePSdata/xef2_1.0-60.1eV/xef2_1.0-60.1eV_orb13_E1G.html</a><br><br>For '
#                               'more details of the calculations, see '
#                               'readme.txt, or: <ul><li><a '
#                               'href="https://phockett.github.io/ePSdata/about.html">About '
#                               'ePSdata</a></li><li><a '
#                               'href="http://epsproc.readthedocs.io/en/latest/about.html">About '
#                               'ePSproc</a></li><li><a '
#                               'href="http://www.chem.tamu.edu/rgroup/lucchese/ePolyScat.E3.manual/manual.html">About '
#                               'ePS</a></li></ul>',
#                'doi': '',
#                'keywords': ['Data',
#                             'Photoionization',
#                             'Scattering calculation'],
#                'license': 'CC-BY-4.0',
#                'prereserve_doi': {'doi': '10.5281/zenodo.3676895',
#                                   'recid': 3676895},
#                'publication_date': '2020-02-20',
#                'title': 'ePSproc: xef2 wavefn run, orb 13 ioinzation (Iodine '
#                         '3d, E1G/PG), 1-60eV',
#                'upload_type': 'dataset'},
#   'modified': '2020-02-20T13:40:39.231328',
#   'owner': 85765,
#   'record_id': 3676895,
#   'state': 'unsubmitted',
#   'submitted': False,
#   'title': 'ePSproc: xef2 wavefn run, orb 13 ioinzation (Iodine 3d, E1G/PG), '
#            '1-60eV'}]

# %%
for item in response.json():
    print('\n***')
    print(item['title'])
    print(item['id'])
    
    if 'files' in item.keys():
        for m, file in enumerate(item['files']):
            print(f"File {m}: {file['filename']}")
            print(f"Size: {file['filesize']}")
# Out:
# ***
# ePSproc: xef2 wavefn test run, orb 21 ioinzation (Iodine 4d, A1G/SG), 1-60eV
# 3676899
# File 0: readme.txt
# Size: 863
# File 1: xef2_1.0-60.1eV_orb21_A1G.ipynb
# Size: 811379
# File 2: xef2_1.0-60.1eV_orb21_A1G.md
# Size: 2301
# File 3: xef2_1.0-60.1eV_orb21_A1G.json
# Size: 38109
# File 4: xef2_1.0-60.1eV_orb21_A1G.zip
# Size: 19308472
#
# ***
# ePSproc: xef2 wavefn run, orb 12 ioinzation (Iodine 3d, A1G/SG), 1-60eV
# 3676893
# File 0: readme.txt
# Size: 863
# File 1: xef2_1.0-60.1eV_orb12_A1G.ipynb
# Size: 784717
# File 2: xef2_1.0-60.1eV_orb12_A1G.md
# Size: 2276
# File 3: xef2_1.0-60.1eV_orb12_A1G.json
# Size: 38074
# File 4: xef2_1.0-60.1eV_orb12_A1G.zip
# Size: 19271073
#
# ***
# ePSproc: xef2 wavefn test run, orb 24 ioinzation (Iodine 4d, E2G/DG), 1-60eV
# 3676903
# File 0: readme.txt
# Size: 863
# File 1: xef2_1.0-60.1eV_orb24_E2G.ipynb
# Size: 837774
# File 2: xef2_1.0-60.1eV_orb24_E2G.md
# Size: 2301
# File 3: xef2_1.0-60.1eV_orb24_E2G.json
# Size: 54717
# File 4: xef2_1.0-60.1eV_orb24_E2G.zip
# Size: 32434456
#
# ***
# ePSproc: xef2 wavefn test run, orb 22 ioinzation (Iodine 4d, E1G/PG), 1-60eV
# 3676901
# File 0: readme.txt
# Size: 863
# File 1: xef2_1.0-60.1eV_orb22_E1G.ipynb
# Size: 866260
# File 2: xef2_1.0-60.1eV_orb22_E1G.md
# Size: 2301
# File 3: xef2_1.0-60.1eV_orb22_E1G.json
# Size: 54717
# File 4: xef2_1.0-60.1eV_orb22_E1G.zip
# Size: 30430091
#
# ***
# ePSproc: xef2 wavefn run, orb 15 ioinzation (Iodine 3d, E2G/DG), 1-60eV
# 3676897
# File 0: readme.txt
# Size: 863
# File 1: xef2_1.0-60.1eV_orb15_E2G.ipynb
# Size: 753785
# File 2: xef2_1.0-60.1eV_orb15_E2G.md
# Size: 2276
# File 3: xef2_1.0-60.1eV_orb15_E2G.json
# Size: 54672
# File 4: xef2_1.0-60.1eV_orb15_E2G.zip
# Size: 32245188
#
# ***
# ePSproc: xef2 wavefn run, orb 13 ioinzation (Iodine 3d, E1G/PG), 1-60eV
# 3676895
# File 0: readme.txt
# Size: 863
# File 1: xef2_1.0-60.1eV_orb13_E1G.ipynb
# Size: 856184
# File 2: xef2_1.0-60.1eV_orb13_E1G.md
# Size: 2276
# File 3: xef2_1.0-60.1eV_orb13_E1G.json
# Size: 54672
# File 4: xef2_1.0-60.1eV_orb13_E1G.zip
# Size: 30227423

# %%
type(response.json()) == dict
# Out:
# True

# %%
if response.json() and (type(response.json()) == dict) and ('status' in response.json().keys()) and response.json()['status'] == 500:
    print(response.json()['status'])
# Out:
# 500

# %%
#**** Remove all items from Zendod (unpublished only)
for item in response.json():
    print(item['id'])
    r = requests.delete('https://zenodo.org/api/deposit/depositions/%s' % item['id'],
                    params={'access_token': ACCESS_TOKEN})
    print(r.status_code)
    
    if r.status_code == 204:
        print('***Item removed')
# Out:
# 3626255
# 204
# ***Item removed

# %%
#*** Remove files from repo (unpublished only)

for item in response.json():
    print(item['id'])
    if 'files' in item.keys():
        for fileItem in item['files']:
            r = requests.delete(f"https://zenodo.org/api/deposit/depositions/{item['id']}/files/{fileItem['id']}",
                            params={'access_token': ACCESS_TOKEN})
            print(r.status_code)

            if r.status_code == 204:
                print('***Item removed')

#         print(f"https://zenodo.org/api/deposit/depositions/{item['id']}/files/{fileItem['id']}")
# Out:
# 3660714
# 3660716
# 3660700
# 204
# ***Item removed
# 204
# ***Item removed
# 204
# ***Item removed
# 204
# ***Item removed
# 204
# ***Item removed
# 3660702
# 204
# ***Item removed
# 204
# ***Item removed
# 204
# ***Item removed
# 204
# ***Item removed
# 204
# ***Item removed
# 204
# ***Item removed
# 3660704
# 204
# ***Item removed
# 204
# ***Item removed
# 204
# ***Item removed
# 204
# ***Item removed
# 204
# ***Item removed
# 204
# ***Item removed
# 3660710
# 204
# ***Item removed
# 204
# ***Item removed
# 204
# ***Item removed
# 204
# ***Item removed
# 204
# ***Item removed
# 204
# ***Item removed
# 3660708
# 204
# ***Item removed
# 204
# ***Item removed
# 204
# ***Item removed
# 204
# ***Item removed
# 204
# ***Item removed
# 3660712
# 204
# ***Item removed
# 204
# ***Item removed
# 204
# ***Item removed
# 204
# ***Item removed
# 204
# ***Item removed

# %%
with open('/home/femtolab/python/epsman/tests/aniline_bemo_nbProc.json') as json_file:
    test = json.load(json_file)

pp.pprint(test)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-112-3b2439814bde> in <module>
#       2 #     test = json.load(json_file)
#       3
# ----> 4 test = json.load('/home/femtolab/python/epsman/tests/aniline_bemo_nbProc.json')
#       5 pp.pprint(test)
#
# ~/anaconda3/envs/epsdev/lib/python3.7/json/__init__.py in load(fp, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     291     kwarg; otherwise ``JSONDecoder`` is used.
#     292     """
# --> 293     return loads(fp.read(),
#     294         cls=cls, object_hook=object_hook,
#     295         parse_float=parse_float, parse_int=parse_int,
#
# AttributeError: 'str' object has no attribute 'read'

# %%
Path('/home/femtolab/python/epsman/tests/aniline_bemo_nbProc.json').is_file()
# Out:
# True

# %%
# Test job title recognition...
testTitle = 'Aniline Orb 24 (A2) ionization'
r = requests.get('https://zenodo.org/api/deposit/depositions',
                        params={'q': testTitle, 'access_token': ACCESS_TOKEN})

# pp = pprint.PrettyPrinter(indent=1)
# pp.pprint(response.json()[0])

# BASIC search grabs also similar titles, so will need to check more carefully.
if r.json():
    print(f"Found possible repo matches...")
    
    
    if len(r.json()) > 1:
        print(f"***Warning: found {len(r.json())} matching repo records...")
        for n, item in enumerate(r.json()):
            print(f"Record {n}: {item['title']}, created {item['created']}")

        record = input('Set record to use: ')
        # r.json() = r.json()[record]
    else:
        record = 0  #r.json() = r.json()[0]
# Out:
# {'conceptrecid': '3612482',
#  'created': '2020-01-19T14:25:17.066714',
#  'doi': '',
#  'doi_url': 'https://doi.org/',
#  'id': 3612483,
#  'links': {'discard': 'https://zenodo.org/api/deposit/depositions/3612483/actions/discard',
#            'edit': 'https://zenodo.org/api/deposit/depositions/3612483/actions/edit',
#            'files': 'https://zenodo.org/api/deposit/depositions/3612483/files',
#            'html': 'https://zenodo.org/deposit/3612483',
#            'publish': 'https://zenodo.org/api/deposit/depositions/3612483/actions/publish',
#            'self': 'https://zenodo.org/api/deposit/depositions/3612483'},
#  'metadata': {'access_right': 'open',
#               'creators': [{'affiliation': 'National Research Council of '
#                                            'Canada',
#                             'name': 'Hockett, Paul',
#                             'orcid': '0000-0001-9561-8433'}],
#               'description': 'Aniline Orb 23 (B1) ionization - photoionization '
#                              'calculations with ePolyScat + ePSproc.\n'
#                              '*Web version*: <a '
#                              'href="https://phockett.github.io/ePSdata/aniline/aniline_wf_0.1-10.1eV_orb23_B1.html">https://phockett.github.io/ePSdata/aniline/aniline_wf_0.1-10.1eV_orb23_B1.html</a>\n'
#                              'For more details of the calculations, see: '
#                              '<ul><li><a '
#                              'href="https://phockett.github.io/ePSdata/about.html">About '
#                              'the data</a></li><li><a '
#                              'href="http://epsproc.readthedocs.io">About the '
#                              'analysis</a></li></ul>',
#               'doi': '',
#               'keywords': ['Data', 'Photoionization', 'Scattering calculation'],
#               'license': 'CC-BY-4.0',
#               'prereserve_doi': {'doi': '10.5281/zenodo.3612483',
#                                  'recid': 3612483},
#               'publication_date': '2020-01-19',
#               'title': 'ePSproc: Aniline Orb 23 (B1) ionization',
#               'upload_type': 'dataset'},
#  'modified': '2020-01-19T14:25:17.066722',
#  'owner': 85765,
#  'record_id': 3612483,
#  'state': 'unsubmitted',
#  'submitted': False,
#  'title': 'ePSproc: Aniline Orb 23 (B1) ionization'}
